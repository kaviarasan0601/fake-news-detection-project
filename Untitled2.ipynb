# %% [markdown]
# <a href="https://colab.research.google.com/github/kaviarasan0601/fake-news-detection-project/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fake_df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      1
# 1  December 31, 2017      1
# 2  December 30, 2017      1
# 3  December 29, 2017      1
# 4  December 25, 2017      1

# %%
df = pd.concat([true_df, fake_df], ignore_index=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['label'], test_size=0.2, random_state=42)

# %%
X_test
# Out:
# 22216    Donald Trump s White House is in chaos, and th...
# 27917    Now that Donald Trump is the presumptive GOP n...
# 25007    Mike Pence is a huge homophobe. He supports ex...
# 1377     SAN FRANCISCO (Reuters) - California Attorney ...
# 32476    Twisted reasoning is all that comes from Pelos...
#                                ...
# 42119    Hillary s over-the-top plan to tax the consume...
# 4068     WASHINGTON (Reuters) - President Donald Trump ...
# 22498    Donald Trump s White House is the leakiest in ...
# 14658    ANKARA (Reuters) - Iran rejected as  wrong  so...
# 15236    DUBAI (Reuters) - French President Emmanuel Ma...
# Name: text, Length: 8980, dtype: object

# %%
X_train
# Out:
# 36335    This story is from 2006 and is the first in a ...
# 12384    PARIS (Reuters) - The leaders of the European ...
# 24419    Star Wars icon Mark Hamill previously mocked D...
# 24740    The whiner-in-chief struck again with yet anot...
# 27039    Donald Trump doesn t have much foreign policy ...
#                                ...
# 11284    ABUJA (Reuters) - The United States has formal...
# 44732    Tune in to the Alternate Current Radio Network...
# 38158     I m convinced the Freedom From Religion group...
# 860      WASHINGTON (Reuters) - The Republican tax plan...
# 15795    SYDNEY (Reuters) - The U.N. High Commissioner ...
# Name: text, Length: 35918, dtype: object

# %%
X_train.shape
# Out:
# (35918,)

# %%
y_train
# Out:
# 36335    1
# 12384    0
# 24419    1
# 24740    1
# 27039    1
#         ..
# 11284    0
# 44732    1
# 38158    1
# 860      0
# 15795    0
# Name: label, Length: 35918, dtype: int64

# %%
model = make_pipeline(TfidfVectorizer(), MultinomialNB())
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
model = make_pipeline(TfidfVectorizer(), MultinomialNB())
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
# Make predictions on the test set
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([1, 1, 1, ..., 1, 0, 0])

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
classification_report_result = classification_report(y_test, predictions)

# %%
accuracy
# Out:
# 0.9387527839643652

# %%
# Display the result
print(f'Accuracy: {accuracy}')
print('Classification Report:\n', classification_report_result)

# %%
#Take input from the user
user_input = input("Enter a news article: ")

# Make a prediction
prediction = model.predict([user_input])

# Display the result
if prediction[0] == 0:
    print("The news is likely to be true.")
else:
    print("The news is likely to be fake.")
# Out:
# Enter a news article: Fake news detection program
# The news is likely to be fake.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, classification_report

from google.colab import files
uploaded=files.upload()
true_df = pd.read_csv('True.csv')
true_df['label'] = 0 # Add a label column for true news
# Out:
#      <input type="file" id="files-c296b3df-1d6e-4824-a324-1e42acd9e6a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c296b3df-1d6e-4824-a324-1e42acd9e6a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
